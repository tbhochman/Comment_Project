# %%
import csv

description = "In the first semester, we covered the fundamentals of Python, including loops, conditionals, functions, and dictionaries. In addition, we explored connections between math and computer science, including plotting, simulating the game of craps, and optimizing customer service at a bank."
students = [] #create empy lists for all the data in teacher.csv
last_names = []
genders = []
reflections = []
problem_sets = []
quizzes = []
assignments = []
final_exams = []
bank_projects = []
final_grades = []
fun = []

with open('teacher.csv') as csvfile: #open the csv and append each row to a separate list
    teacher = csv.reader(csvfile, delimiter=',')
    header = csvfile.readline()
    for row in teacher:
        print(row)
        students.append(row[0])
        last_names.append(row[1])
        genders.append(row[2])
        reflections.append(row[-1])
        final_grades.append(row[3])
        problem_sets.append(row[6])
        quizzes.append(row[5])
        assignments.append(row[8])
        final_exams.append(row[4])
        bank_projects.append(row[7])
        fun.append(row[9])

        
def get_pronoun(gender): 
    '''returns the student's prefered pronoun given their gender'''
    if gender == 'M':
        return 'he'
    if gender == 'F':
        return 'she'
    else:
        return 'they'

def get_possessive(gender):
    '''returns the student's prefered pronoun in possessive form given their gender'''
    if gender == 'M':
        return 'his'
    if gender == 'F':
        return 'her'
    else:
        return 'their'

def get_pasttense(gender):
    '''returns verb conjugation of was/were given their gender'''
    if gender == 'M' or gender == 'F':
        return 'was'
    else:
        return 'were'

def get_object(gender):
    '''returns object form given their gender'''
    if gender == 'M':
        return 'him'
    if gender == 'F':
        return 'her'
    else:
        return 'them'
    
def get_overallperformance(i,student):
    '''returns the paragraph for overall performance given the student's final grade in the class'''
    if int(final_grades[i]) >= 90:
        return f"I am pleased with {student}’s progress this semester. As such, {possessive} problem set average was {problem_sets[i]}%, which indicates that {pronoun} had a solid understanding of the majority of the topics covered this semester and that {pronoun} {past_tense} consistent about meeting deadlines. For {possessive} quiz average and final exam score, {student} got {quizzes[i]}% and {final_exams[i]}%, respectively, which demonstrated that {pronoun} grasped the new content thoroughly and could hand write algorithms without using outside resources.\n"
    elif int(final_grades[i]) >= 80: 
        return f"I appreciate {student}’s energy this semester. While it is clear that Computer Science was perhaps not {possessive} preferred class choice, {pronoun} still performed well throughout the semester. As such, {student}'s problem set average was {problem_sets[i]}%, which indicates that {pronoun} had a decent understanding of the majority of the topics covered this semester and that {pronoun} {past_tense} somewhat consistent about meeting deadlines. For {possessive} quiz average and final exam score, {student} got {quizzes[i]}% and {final_exams[i]}%, respectively, which demonstrated that {pronoun} satisfactorily grasped the new content thoroughly and could often hand write algorithms without using outside resources.\n"
    else:
        return f"Admittedly, {student} struggled this semester, but {possessive} perseverance despite Computer Science not being {possessive} favorite class was admirable. As such, {possessive} problem set average was {problem_sets[i]}%, which indicates that {pronoun} had difficulty understanding some of the topics covered this semester and that {pronoun} {past_tense} sometimes inconsistent when it came to meeting deadlines. For {possessive} quiz average and final exam score, {pronoun} got {quizzes[i]}% and {final_exams[i]}%, respectively, which demonstrated that {pronoun} did not always grasp the new content thoroughly.\n"

def get_dailywork(i,student):
    '''returns the paragraph for daily work given the student's assignment grade average in the class'''
    if int(assignments[i]) >= 95:
        return f"On the daily coding activities, {student} worked mostly by {direct_object}self since the material came easily to {direct_object}, but {pronoun} was happy to help a classmate when they got stuck. In regard to using available resources like StackOverflow, {pronoun} wisely utilized these resources to troubleshoot and gain inspiration and internalized the solutions that {pronoun} found. In terms of coming in for extra help, {student} rarely, if ever, needed to do so because {pronoun} was so easily able to pick up the concepts in class.\n"
    elif int(assignments[i]) >= 90:
        return f"On the daily coding activities, {student} generally worked collaboratively since {pronoun} mostly understood the material, but it did not always come easily. Often, {pronoun} would help a classmate when they got stuck, or vice versa. In regard to using available resources like StackOverflow, {student} occasionally utilized these resources to troubleshoot and gain inspiration and internalized the solutions that {pronoun} found. In terms of coming in for extra help, {pronoun} sometimes came in for support, but I wish {pronoun} would have done so more often as it may have taken {direct_object} to the next level.\n"
    else:
        return f"On the daily coding activities, {student} mostly worked collaboratively since {pronoun} did not always pick up the material as easily as others. Often, {pronoun} would seek help from a classmate when {pronoun} got stuck. In terms of coming in for extra help, {student} occasionally came in for support, but I wish {pronoun} would have done so more often as it may have improved {possessive} success in the class.\n"
    
def get_bankingproject(i,student):
    '''returns the paragraph for the banking project given the student's bank project grade'''
    if int(bank_projects[i]) >= 95:
        return f"{student}’s group Bank Project grade was a {bank_projects[i]}%, which indicated that {possessive} effort, time management, and collaboration relating to larger group assignments were excellent. In addition, {pronoun} demonstrated significant enthusiasm and dedication when participating in the Hackathons. These assignments allowed students to put forth as much effort as they wished to, and {student} chose to use these opportunities to seriously challenge {direct_object}self, think creatively, and advance {possessive} skills.\n"
    elif int(bank_projects[i]) >= 90:
        return f"{student}’s group Bank Project grade was a {bank_projects[i]}%, which indicated that {possessive} effort, time management, and collaboration relating to larger group assignments were decent, although towards the end of the semester {pronoun} seemed to occasionally be struggling to concentrate. {student} demonstrated a relative degree of enthusiasm and dedication when participating in the Hackathons. These assignments allowed students to put forth as much effort as they wished to, and {student} generally chose to use these opportunities to challenge {direct_object}self and advance {possessive} skills.\n"
    else:
        return f"{student}’s group Bank Project grade was a {bank_projects[i]}%, which indicated that {possessive} effort, time management, and collaboration relating to larger group assignments were lacking. {student} also demonstrated a dearth of enthusiasm and dedication when participating in the Hackathons. These assignments allowed students to put forth as much effort as they wished to, and {student} generally chose to use these opportunities to rely on those around {direct_object} instead of trying to advance {possessive} skills.\n"

def get_fun(i,students):
    '''returns the paragraph for how fun the student is given their fun level'''
    if int(fun[i]) == 3:
        return f"Overall, {student}, without a doubt, had unbelievable amounts of fun in this class. More often than not, {pronoun} could be found wearing a pink unicorn uni-suit, humming to {direct_object}self as {pronoun} typed away. I’m not sure if it’s the cannabis legalization or the vibrations in the classroom, but {student} was just… ultra stoked on life this semester.\n"
    if int(fun[i]) == 2:
        return f"Overall, {student} seemed to generally enjoy {direct_object}self in this class. Generally, {pronoun} was upbeat as {pronoun} typed away. I hope that {student} enjoyed {possessive} first semester of Comp Sci!\n"
    else:
        return f"Ok. One last thing. Let me lay this out for you. If {student} were in Winnie the Pooh, {pronoun}’d be Eeyore. For hours on end, it seemed, {pronoun} would sit forlornly in the corner staring out the window imagining what I can only guess is the most efficient path towards their own defenestration. {student}'s verbal inflection was painfully monotonal, as it seemed that all vestiges of happiness and positive mental dispositions had been torn out of {possessive} existence. I really have nowhere to point {student}, as it seems that {pronoun} is destined to live out {possessive} days as a hermit in some far off abandoned island as far away from human contact as {pronoun} can possibly get.\n"
    
for i, student in enumerate(students): #loops through students 
    print(f"{student} {last_names[i]}:\n") #prints out the full name of the student
    with open(student.lower()+'.txt', 'w') as f: #creates a .txt for each student
        pronoun = get_pronoun(genders[i]) #stores the student's pronoun
        possessive = get_possessive(genders[i]) #stores the student's pronoun in possessive form
        past_tense = get_pasttense(genders[i]) #stores the past tense for the student's pronoun
        direct_object = get_object(genders[i]) #stores the object form of the student's pronoun
        f.write(description+'\n') #writes the description of the course into the comments
        f.write(get_overallperformance(i,student)) #writes the overall performance of the student
        f.write(f"In {student}'s self reflection, {pronoun} wrote: \n\t{reflections[i]}\n") #writes student's self reflection into comment
        f.write(get_dailywork(i,student)) #writes daily work paragraph for student
        f.write(get_bankingproject(i,student)) #writes paragraph about banking project for student
        f.write(get_fun(i,student)) #writes the paragraph for how fun the student was
        f.close()

    for line in open(student.lower()+'.txt'):
        print(line) #prints each student's file
# Out:
# ['Kanye', 'West', 'M', '88', '87', '82', '88', '98', '92', '3', 'Scoop de woop de poop. Woop diddy scoop poop.']
# ['Grape', 'Jelly', 'M', '76', '56', '61', '76', '90', '84', '1', 'I hate this class. Which is why I never show up. Have a grape day.']
# ['Strawberry', 'Jam', 'F', '98', '98', '99', '95', '95', '100', '2', 'You jammed a lot of material in this semester, but when I straw my grade and thought, that is berry good. ']
# ['Raspberry', 'Icee', 'F', '98', '92', '95', '98', '100', '99', '2', "Icee you think I'm pretty clever. "]
# ['Banana', 'Milkshake', 'M', '93', '94', '90', '92', '98', '95', '3', 'I am bananas for comp sci. ']
# ['Blackberry', 'Smoothie', 'T', '77', '63', '66', '73', '89', '87', '2', "Can't say this was all smoothie sailing for me. I definitely struggled with all of the quizzes."]
# ['Lemon', 'Bar', 'M', '87', '78', '85', '80', '93', '94', '2', 'Barring the final, I enjoyed the vast majority of this class. Please lemon retake the final. ']
# ['Kiwi', 'Pie', 'F', '82', '75', '74', '80', '89', '88', '2', "Pie couldn't have cared less about this class"]
# ['Orange', 'Soda', 'F', '97', '90', '93', '98', '100', '98', '3', 'Orange you glad I found success in this class?']
# ['Apple', 'Strudel', 'M', '87', '80', '82', '84', '90', '93', '3', 'Ich bin ein "Apfel" von Wertschatzung fur diesen Kurs']
# ['Huckleberry', 'Finn', 'M', '97', '99', '97', '100', '98', '95', '2', "Jim said that bees won't sting idiots, but I didn't believe that, because I tried them lots of times myself and they wouldn't sting me."]
# ['Tomato', 'Ketchup', 'F', '90', '86', '84', '90', '95', '93', '3', 'Comp sci is my favorite class. I love figuring out a difficult problem. It makes me shiver from my head tomatoes.']
# ['Water', 'Melon', 'T', '93', '89', '93', '92', '90', '94', '3', 'I trust your evaluation, so I think a self-reflection is not necessary. Water you think about my progress this year?']
# ['Pear', 'Cider', 'M', '88', '85', '83', '89', '89', '90', '2', 'I really enjoyed the bank project this year, you peared me with really great fruits. I learned a lot.']
# ['Passion', 'Fruit', 'F', '98', '100', '100', '99', '100', '95', '1', "I am extremely passionate about computer science, so I really think this class was overall an extremely satisfactory experience. I've already taken a couple of comp sci courses so none of the material was new to me and I felt that all of the assignments, problem sets, and quizzes were extremely easy."]
# Kanye West:
#
# In the first semester, we covered the fundamentals of Python, including loops, conditionals, functions, and dictionaries. In addition, we explored connections between math and computer science, including plotting, simulating the game of craps, and optimizing customer service at a bank.
#
# I appreciate Kanye’s energy this semester. While it is clear that Computer Science was perhaps not his preferred class choice, he still performed well throughout the semester. As such, Kanye's problem set average was 88%, which indicates that he had a decent understanding of the majority of the topics covered this semester and that he was somewhat consistent about meeting deadlines. For his quiz average and final exam score, Kanye got 82% and 87%, respectively, which demonstrated that he satisfactorily grasped the new content thoroughly and could often hand write algorithms without using outside resources
asped the new content thoroughly and could hand write algorithms without using outside resources.
#
# In Raspberry's self reflection, she wrote:
#
# 	Icee you think I'm pretty clever.
#
# On the daily coding activities, Raspberry worked mostly by herself since the material came easily to her, but she was happy to help a classmate when they got stuck. In regard to using available resources like StackOverflow, she wisely utilized these resources to troubleshoot and gain inspiration and internalized the solutions that she found. In terms of coming in for extra help, Raspberry rarely, if ever, needed to do so because she was so easily able to pick up the concepts in class.
#
# Raspberry’s group Bank Project grade was a 100%, which indicated that her effort, time management, and collaboration relating to larger group assignments were excellent. In addition, she demonstrated significant enthusiasm and dedication when participating in the Hackathons. These assignments allowed students to put forth as much effort as they wished to, and Raspberry chose to use these opportunities to seriously challenge herself, think creatively, and advance her skills.
#
# Overall, Raspberry seemed to generally enjoy herself in this class. Generally, she was upbeat as she typed away. I hope that Raspberry enjoyed her first semester of Comp Sci!
#
# Banana Milkshake:
#
# In the first semester, we covered the fundamentals of Python, including loops, conditionals, functions, and dictionaries. In addition, we explored connections between math and computer science, including plotting, simulating the game of craps, and optimizing customer service at a bank.
#
# I am pleased with Banana’s progress this semester. As such, his problem set average was 92%, which indicates that he had a solid understanding of the majority of the topics covered this semester and that he was consistent about meeting deadlines. For his quiz average and final exam score, Banana got 90% and 94%, respectively, which demonstrated that he grasped the new content thoroughly and could hand write algorithms without using outside resources.
#
# In Banana's self reflection, he wrote:
#
# 	I am bananas for comp sci.
#
# On the daily coding activities, Banana worked mostly by himself since the material came easily to him, but he was happy to help a classmate when they got stuck. In regard to using available resources like StackOverflow, he wisely utilized these resources to troubleshoot and gain inspiration and internalized the solutions that he found. In terms of coming in for extra help, Banana rarely, if ever, needed to do so because he was so easily able to pick up the concepts in class.
#
# Banana’s group Bank Project grade was a 98%, which indicated that his effort, time management, and collaboration relating to larger group assignments were excellent. In addition, he demonstrated significant enthusiasm and dedication when participating in the Hackathons. These assignments allowed students to put forth as much effort as they wished to, and Banana chose to use these opportunities to seriously challenge himself, think creatively, and advance his skills.
#
# Overall, Banana, without a doubt, had unbelievable amounts of fun in this class. More often than not, he could be found wearing a pink unicorn uni-suit, humming to himself as he typed away. I’m not sure if it’s the cannabis legalization or the vibrations in the classroom, but Banana was just… ultra stoked on life this semester.
#
# Blackberry Smoothie:
#
# In the first semester, we covered the fundamentals of Python, including loops, conditionals, functions, and dictionaries. In addition, we explored connections between math and computer science, including plotting, simulating the game of craps, and optimizing customer service at a bank.
#
# Admittedly, Blackberry struggled this semester, but their perseverance despite Computer Science not being their favorite class was admirable. As such, their problem set average was 73%, which indicates that they had difficulty understanding some of the topics covered this semester and that they were sometimes inconsistent when it came to meeting deadlines. For their quiz average and final exam score, they got 66% and 63%, respectively, which demonstrated that they did not always grasp the new content thoroughly.
#
# In Blackberry's self reflection, they wrote:
#
# 	Can't say this was all smoothie sailing for me. I definitely struggled with all of the quizzes.
#
# On the daily coding activities, Blackberry mostly worked collaboratively since they did not always pick up the material as easily as others. Often, they would seek help from a classmate when they got stuck. In terms of coming in for extra help, Blackberry occasionally came in for support, but I wish they would have done so more often as it may have improved their success in the class.
#
# Blackberry’s group Bank Project grade was a 89%, which indicated that their effort, time management, and collaboration relating to larger group assignments were lacking. Blackberry also demonstrated a dearth of enthusiasm and dedication when participating in the Hackathons. These assignments allowed students to put forth as much effort as they wished to, and Blackberry generally chose to use these opportunities to rely on those around them instead of trying to advance their skills.
#
# Overall, Blackberry seemed to generally enjoy themself in this class. Generally, they was upbeat as they typed away. I hope that Blackberry enjoyed their first semester of Comp Sci!
#
# Lemon Bar:
#
# In the first semester, we covered the fundamentals of Python, including loops, conditionals, functions, and dictionaries. In addition, we explored connections between math and computer science, including plotting, simulating the game of craps, and optimizing customer service at a bank.
#
# I appreciate Lemon’s energy this semester. While it is clear that Computer Science was perhaps not his preferred class choice, he still performed well throughout the semester. As such, Lemon's problem set average was 80%, which indicates that he had a decent understanding of the majority of the topics covered this semester and that he was somewhat consistent about meeting deadlines. For his quiz average and final exam score, Lemon got 85% and 78%, respectively, which demonstrated that he satisfactorily grasped the new content thoroughly and could often hand write algorithms without using outside resources.
#
# In Lemon's self reflection, he wrote:
#
# 	Barring the final, I enjoyed the vast majority of this class. Please lemon retake the final.
#
# On the daily coding activities, Lemon generally worked collaboratively since he mostly understood the material, but it did not always come easily. Often, he would help a classmate when they got stuck, or vice versa. In regard to using available resources like StackOverflow,
enthusiasm and dedication when participating in the Hackathons. These assignments allowed students to put forth as much effort as they wished to, and Apple generally chose to use these opportunities to challenge himself and advance his skills.
#
# Overall, Apple, without a doubt, had unbelievable amounts of fun in this class. More often than not, he could be found wearing a pink unicorn uni-suit, humming to himself as he typed away. I’m not sure if it’s the cannabis legalization or the vibrations in the classroom, but Apple was just… ultra stoked on life this semester.
#
# Huckleberry Finn:
#
# In the first semester, we covered the fundamentals of Python, including loops, conditionals, functions, and dictionaries. In addition, we explored connections between math and computer science, including plotting, simulating the game of craps, and optimizing customer service at a bank.
#
# I am pleased with Huckleberry’s progress this semester. As such, his problem set average was 100%, which indicates that he had a solid understanding of the majority of the topics covered this semester and that he was consistent about meeting deadlines. For his quiz average and final exam score, Huckleberry got 97% and 99%, respectively, which demonstrated that he grasped the new content thoroughly and could hand write algorithms without using outside resources.
#
# In Huckleberry's self reflection, he wrote:
#
# 	Jim said that bees won't sting idiots, but I didn't believe that, because I tried them lots of times myself and they wouldn't sting me.
#
# On the daily coding activities, Huckleberry worked mostly by himself since the material came easily to him, but he was happy to help a classmate when they got stuck. In regard to using available resources like StackOverflow, he wisely utilized these resources to troubleshoot and gain inspiration and internalized the solutions that he found. In terms of coming in for extra help, Huckleberry rarely, if ever, needed to do so because he was so easily able to pick up the concepts in class.
#
# Huckleberry’s group Bank Project grade was a 98%, which indicated that his effort, time management, and collaboration relating to larger group assignments were excellent. In addition, he demonstrated significant enthusiasm and dedication when participating in the Hackathons. These assignments allowed students to put forth as much effort as they wished to, and Huckleberry chose to use these opportunities to seriously challenge himself, think creatively, and advance his skills.
#
# Overall, Huckleberry seemed to generally enjoy himself in this class. Generally, he was upbeat as he typed away. I hope that Huckleberry enjoyed his first semester of Comp Sci!
#
# Tomato Ketchup:
#
# In the first semester, we covered the fundamentals of Python, including loops, conditionals, functions, and dictionaries. In addition, we explored connections between math and computer science, including plotting, simulating the game of craps, and optimizing customer service at a bank.
#
# I am pleased with Tomato’s progress this semester. As such, her problem set average was 90%, which indicates that she had a solid understanding of the majority of the topics covered this semester and that she was consistent about meeting deadlines. For her quiz average and final exam score, Tomato got 84% and 86%, respectively, which demonstrated that she grasped the new content thoroughly and could hand write algorithms without using outside resources.
#
# In Tomato's self reflection, she wrote:
#
# 	Comp sci is my favorite class. I love figuring out a difficult problem. It makes me shiver from my head tomatoes.
#
# On the daily coding activities, Tomato generally worked collaboratively since she mostly understood the material, but it did not always come easily. Often, she would help a classmate when they got stuck, or vice versa. In regard to using available resources like StackOverflow, Tomato occasionally utilized these resources to troubleshoot and gain inspiration and internalized the solutions that she found. In terms of coming in for extra help, she sometimes came in for support, but I wish she would have done so more often as it may have taken her to the next level.
#
# Tomato’s group Bank Project grade was a 95%, which indicated that her effort, time management, and collaboration relating to larger group assignments were excellent. In addition, she demonstrated significant enthusiasm and dedication when participating in the Hackathons. These assignments allowed students to put forth as much effort as they wished to, and Tomato chose to use these opportunities to seriously challenge herself, think creatively, and advance her skills.
#
# Overall, Tomato, without a doubt, had unbelievable amounts of fun in this class. More often than not, she could be found wearing a pink unicorn uni-suit, humming to herself as she typed away. I’m not sure if it’s the cannabis legalization or the vibrations in the classroom, but Tomato was just… ultra stoked on life this semester.
#
# Water Melon:
#
# In the first semester, we covered the fundamentals of Python, including loops, conditionals, functions, and dictionaries. In addition, we explored connections between math and computer science, including plotting, simulating the game of craps, and optimizing customer service at a bank.
#
# I am pleased with Water’s progress this semester. As such, their problem set average was 92%, which indicates that they had a solid understanding of the majority of the topics covered this semester and that they were consistent about meeting deadlines. For their quiz average and final exam score, Water got 93% and 89%, respectively, which demonstrated that they grasped the new content thoroughly and could hand write algorithms without using outside resources.
#
# In Water's self reflection, they wrote:
#
# 	I trust your evaluation, so I think a self-reflection is not necessary. Water you think about my progress this year?
#
# On the daily coding activities, Water generally worked collaboratively since they mostly understood the material, but it did not always come easily. Often, they would help a classmate when they got stuck, or vice versa. In regard to using available resources like StackOverflow, Water occasionally utilized these resources to troubleshoot and gain inspiration and internalized the solutions that they found. In terms of coming in for extra help, they sometimes came in for support, but I wish they would have done so more often as it may have taken them to the next level.
#
# Water’s group Bank Project grade was a 90%, which indicated that their effort, time management, and collaboration relating to larger group assignments were decent, although towards the end of the semester they seemed to occasionally be struggling to concentrate. Water demonstrated a relative degree of enthusiasm and dedication when participating in the Hackathons. These assignments allowed students to put forth as much effort as they wished to, and Water generally chose to use these opportunities to challenge themself and advance their skills.
#
# Overall, Water, without a doubt, had unbelievable amounts of fun in this class. More often than not, they could be found wearing a pink unicorn uni-suit, humming to themself as they typed away. I’m not sure if it’s the cannabis legalization or the vibrations in the classroom, but Water was just… ultra stoked on life this semester.
#
# Pear Cider:
#
# In the first semester, we covered the fundamentals of Python, including loops, conditionals, functions, and dictionaries. In addition, we explored connections between math and computer science, including plotting, simulating the game of craps, and optimizing customer service at a bank.
#
# I appreciate Pear’s energy this semester. While it is clear that Computer Science was perhaps not his preferred class choice, he still performed well throughout the semester. As such, Pear's problem set average was 89%, which indicates that he had a decent understanding of the majority of the topics covered this semester and that he was somewhat consistent about meeting deadlines. For his quiz average and final exam score, Pear got 83% and 85%, respectively, which demonstrated that he satisfactorily grasped the new content thoroughly and could often hand write algorithms without using outside resources.
#
# In Pear's self reflection, he wrote:
#
# 	I really enjoyed the bank project this year, you peared me with really great fruits. I learned a lot.
#
# On the daily coding activities, Pear generally worked collaboratively since he mostly understood the material, but it did not always come easily. Often, he would help a classmate when they got stuck, or vice versa. In regard to using available resources like StackOverflow, Pear occasionally utilized these resources to troubleshoot and gain inspiration and internalized the solutions that he found. In terms of coming in for extra help, he sometimes came in for support, but I wish he would have done so more often as it may have taken him to the next level.
#
# Pear’s group Bank Project grade was a 89%, which indicated that his effort, time management, and collaboration relating to larger group assignments were lacking. Pear also demonstrated a dearth of enthusiasm and dedication when participating in the Hackathons. These assignments allowed students to put forth as much effort as they wished to, and Pear generally chose to use these opportunities to rely on those around him instead of trying to advance his skills.
#
# Overall, Pear seemed to generally enjoy himself in this class. Generally, he was upbeat as he typed away. I hope that Pear enjoyed his first semester of Comp Sci!
#
# Passion Fruit:
#
# In the first semester, we covered the fundamentals of Python, including loops, conditionals, functions, and dictionaries. In addition, we explored connections between math and computer science, including plotting, simulating the game of craps, and optimizing customer service at a bank.
#
# I am pleased with Passion’s progress this semester. As such, her problem set average was 99%, which indicates that she had a solid understanding of the majority of the topics covered this semester and that she was consistent about meeting deadlines. For her quiz average and final exam score, Passion got 100% and 100%, respectively, which demonstrated that she grasped the new content thoroughly and could hand write algorithms without using outside resources.
#
# In Passion's self reflection, she wrote:
#
# 	I am extremely passionate about computer science, so I really think this class was overall an extremely satisfactory experience. I've already taken a couple of comp sci courses so none of the material was new to me and I felt that all of the assignments, problem sets, and quizzes were extremely easy.
#
# On the daily coding activities, Passion worked mostly by herself since the material came easily to her, but she was happy to help a classmate when they got stuck. In regard to using available resources like StackOverflow, she wisely utilized these resources to troubleshoot and gain inspiration and internalized the solutions that she found. In terms of coming in for extra help, Passion rarely, if ever, needed to do so because she was so easily able to pick up the concepts in class.
#
# Passion’s group Bank Project grade was a 100%, which indicated that her effort, time management, and collaboration relating to larger group assignments were excellent. In addition, she demonstrated significant enthusiasm and dedication when participating in the Hackathons. These assignments allowed students to put forth as much effort as they wished to, and Passion chose to use these opportunities to seriously challenge herself, think creatively, and advance her skills.
#
# Ok. One last thing. Let me lay this out for you. If Passion were in Winnie the Pooh, she’d be Eeyore. For hours on end, it seemed, she would sit forlornly in the corner staring out the window imagining what I can only guess is the most efficient path towards their own defenestration. Passion's verbal inflection was painfully monotonal, as it seemed that all vestiges of happiness and positive mental dispositions had been torn out of her existence. I really have nowhere to point Passion, as it seems that she is destined to live out her days as a hermit in some far off abandoned island as far away from human contact as she can possibly get.
